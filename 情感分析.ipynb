# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# %matplotlib inline
# load the dataset
dataframe = read_csv(r'C:\Users\Think\Desktop\sentiment.csv')

# %%
seti=pd.DataFrame(dataframe.groupby('recordName')['predictEmotion'].sum())

# %%
cv = pd.read_excel(r'C:\Users\Think\Desktop\CX.xlsx')

# %%
result = pd.merge(cv,seti.reset_index(), on='recordName')

# %%
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
ax=sns.boxplot(x=result['isr'],y=result['predictEmotion'])

# %%
result.groupby('isr')['predictEmotion'].mean()
# Out:
# isr
# 否      1.871413
# 是      1.705462
# 未作答    1.757447
# Name: predictEmotion, dtype: float64

# %%
pd.DataFrame(seti.index).join(seti(''))
# Out:
#                    recordName
# 0     Rec12201509171343535010
# 1     Rec12201510252121125021
# 2     Rec12201511110900455009
# 3     Rec12201511160800145015
# 4     Rec12201511171119285015
# 5     Rec12201512021157315009
# 6     Rec12201512091154415009
# 7     Rec12201512311535465009
# 8     Rec12201602040836305003
# 9     Rec12201602171027425015
# 10    Rec12201602241608415018
# 11    Rec12201603020958235015
# 12    Rec12201603061103435021
# 13    Rec12201603111238135018
# 14    Rec12201604270941445009
# 15    Rec12201605090923195018
# 16    Rec12201605111729185018
# 17    Rec12201606051045505021
# 18    Rec12201606231931405021
# 19    Rec12201606291728585009
# 20    Rec12201606301134335021
# 21    Rec12201606301500325007
# 22    Rec12201606301817005021
# 23    Rec12201607010801225007
# 24    Rec12201607010942555007
# 25    Rec12201607011027445010
# 26    Rec12201607011149055009
# 27    Rec12201607020735365021
# 28    Rec12201607021429535021
# 29    Rec12201607041735175009
# ...

# %%
def count(x):
    a=''
    for item in x:
        if len(str(item))>len(a):
            a=str(item)
    return a
